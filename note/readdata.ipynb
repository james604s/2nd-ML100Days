# %% [markdown]
# # Python 各種讀取資料的方法

# %% [markdown]
# ### pandas 讀取csv檔

# %%
import pandas as pd
df = pd.read_csv('/Users/squid504s/Desktop/GitHub/2nd-ML100Days/data/主題一/bureau.csv')
df
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0            215354       5714462        Closed      currency 1         -497
# 1            215354       5714463        Active      currency 1         -208
# 2            215354       5714464        Active      currency 1         -203
# 3            215354       5714465        Active      currency 1         -203
# 4            215354       5714466        Active      currency 1         -629
# 5            215354       5714467        Active      currency 1         -273
# 6            215354       5714468        Active      currency 1          -43
# 7            162297       5714469        Closed      currency 1        -1896
# 8            162297       5714470        Closed      currency 1        -1146
# 9            162297       5714471        Active      currency 1        -1146
# 10           162297       5714472        Active      currency 1        -1146
# ...

# %% [markdown]
# ### pandas 讀取html

# %%
dfs = pd.read_html('http://rate.bot.com.tw/xrt?Lang=zh-TW')  
dfs[0]
# Out:
#                         幣別              現金匯率 Unnamed: 3_level_0    即期匯率  \
#         Unnamed: 0_level_1     本行買入     本行賣出               本行買入    本行賣出
# 0       美金 (USD)  美金 (USD)    30.44    31.13              30.81   30.91
# 1       港幣 (HKD)  港幣 (HKD)    3.769    3.985              3.905   3.965
# 2       英鎊 (GBP)  英鎊 (GBP)    39.23    41.35              40.23   40.65
# 3       澳幣 (AUD)  澳幣 (AUD)    21.74    22.52              22.01   22.24
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)    22.65    23.56              23.04   23.26
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)    22.24    23.15              22.73   22.91
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)       30     31.2              30.66   30.95
# 7       日圓 (JPY)  日圓 (JPY)   0.2665   0.2793             0.2738  0.2778
# 8     南非幣 (ZAR)  南非幣 (ZAR)        -        -               2.17    2.25
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)     2.95     3.47               3.29    3.39
# 10      紐元 (NZD)  紐元 (NZD)    20.41    21.26              20.79   20.99
# ...

# %% [markdown]
# ### pandas 讀取 JSON

# %%
dj = pd.read_json('/Users/squid504s/Desktop/GitHub/2nd-ML100Days/data/主題一/example01.json')
dj
# Out:
#    id sex  age  score
# 0   1   F   20     77
# 1   2   F   25     90
# 2   3   M   22     80
# 3   4   F   30     66
# 4   5   M   40     60
# 5   6   M   29     87

# %% [markdown]
# ### 讀取txt 方法一

# %%
f = open('/Users/squid504s/Desktop/GitHub/2nd-ML100Days/data/主題一/example.txt')
f.readline() #readline可以只讀一列
# Out:
# 'id,sex,age,score\n'

# %%
for line in f:
    print(line,end="")
# Out:
# 001,F,20,77
# 002,F,25,90
# 003,M,22,80
# 004,F,30,66
# 005,M,40,60
# 006,M,29,87

# %% [markdown]
# ### 讀取txt 方法二

# %%
import pandas as pd
data = []
with open("/Users/squid504s/Desktop/GitHub/2nd-ML100Days/data/主題一/example.txt", 'r',encoding = 'utf8') as f:
    for line in f:
        line = line.split(',')
        data.append(line)
data
df = pd.DataFrame(data)
df
# Out:
#      0    1    2        3
# 0   id  sex  age  score\n
# 1  001    F   20     77\n
# 2  002    F   25     90\n
# 3  003    M   22     80\n
# 4  004    F   30     66\n
# 5  005    M   40     60\n
# 6  006    M   29       87

# %% [markdown]
# ### 讀取txt 方法三

# %%
tx = pd.read_csv('/Users/squid504s/Desktop/GitHub/2nd-ML100Days/data/主題一/example.txt',sep=',')
type(tx)
tx
# Out:
#    id sex  age  score
# 0   1   F   20     77
# 1   2   F   25     90
# 2   3   M   22     80
# 3   4   F   30     66
# 4   5   M   40     60
# 5   6   M   29     87

# %% [markdown]
# ### 讀取圖片

# %%
from skimage import io
img=io.imread('/Users/squid504s/Desktop/test2.png')
io.imshow(img)
