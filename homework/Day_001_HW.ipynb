# %% [markdown]
# ## 作業1：
# 1. 你選的這組資料為何重要？
#
#      近期想往銀行業發展，藉由信用卡違約資料進而了解稍微銀行業相關業務，
#    且此資料集類別、連續型資料、也有資料不平衡的狀況等，可練習特徵萃取、客戶分群及標籤等相關技巧，
#    並利用資料分析方式找出一些違約的行為模式。
#      這個資料集在為臺灣信用卡客戶2005/4~9違約的預測，大概是信用卡風暴前的客戶資料，相當有趣。
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)？
#
#     Lichman, M. (2013). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#     The original dataset can be found here at the UCI Machine Learning Repository.
#
#
# 3. 蒐集而來的資料型態為何？
#
#     結構化資料  CSV
#
#
# 4. 這組資料想解決的問題如何評估？
#
#     哪些變數是影響下個月是否違約的最強因子。
#     是否違約如何因不同的人口統計變數的類別而異。
#     分類正確率問題。
#     混淆矩陣、AUC、Accuracy

# %% [markdown]
# ## 作業2：
#
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)？
#
#     依照不同的地區，有不同類型的店家（如：夜店、酒吧區）或是分析有無活動及節日的人潮量，依照比例分配適量的車數。
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)？
#
#     公司系統蒐集的載客紀錄、附近店家或大眾運輸工具的人潮量。
#
#
# 3. 蒐集而來的資料型態為何？
#
#     結構化資料、CSV
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)？
#
#     當分配完後，與歷史資料相比是否業績有提升。

# %% [markdown]
# ## 作業3：
# #### 請寫一個函式用來計算 Mean Square Error
# #### Hint: 如何取平方

# %% [markdown]
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
###import 計算及視覺化套件
import numpy as np
import matplotlib.pyplot as plt

# %%
###MSE (True-Predict)平方後加總/個數
def mean_squared_error(y, yh):
    
    mse = sum((y-yh)**2)/len(y)
    
    return mse
    
###MAE (True-Predict)絕對值後加總/個數
def mean_absolute_error(y, yp):
    
    mae = sum(abs(y-yp))/len(y)
    
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 215.927
# The Mean absolute error is 11.380
